# %%
import pandas as pd

# %%
data = pd.read_csv('data/student-por.csv', sep=';')

# %%
data.drop(['G1', 'G2', 'Fjob', 'Mjob', 'reason'], axis=1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu guardian  traveltime  \
# 0       GP   F   18       U     GT3       A     4     4   mother           2
# 1       GP   F   17       U     GT3       T     1     1   father           1
# 2       GP   F   15       U     LE3       T     1     1   mother           1
# 3       GP   F   15       U     GT3       T     4     2   mother           1
# 4       GP   F   16       U     GT3       T     3     3   father           1
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...         ...
# 644     MS   F   19       R     GT3       T     2     3   mother           1
# 645     MS   F   18       U     LE3       T     3     1   mother           1
# 646     MS   F   18       U     GT3       T     1     1   mother           2
# 647     MS   M   17       U     LE3       T     3     1   mother           2
# 648     MS   M   18       R     LE3       T     3     2   mother           3
#
# ...

# %% [markdown]
# Convert the numeric data into categorical data. Transform the following columns’ numeric data into categorical data according to the bounds specified below:
#
#     age
#         age < 18: "low"
#         age >= 18: "high"
#
#     failures
#         failures < 2: "low"
#         failures >= 2: "high"
#
#     absences
#         absences < 2: "low"
#         2 <= absences < 10: "medium"
#         10 <= absences: "high"
#
#     G3
#         G < 10: "fail"
#         G >= 10: "pass"
#
#     famrel, freetime, goout, Dalc, Walc, Medu, Fedu, studytime, health: these all have 5 levels, but we can simplify to 2
#         < 3: "low"
#         >= 3: "high"

# %%
cleaned = data.where(data['age'] < 18, 'low').where(data['age'] >= 18, 'high')

# %%
cleaned = data.where(data['failures'] < 2, 'low').where(data['failures'] >= 2, 'high')

# %%
cleaned = data.where(data['absences'] < 2, 'low').where(data['failures'].between(2, 10, inclusive='left'), 'medium').where(data['absences'] >= 10, 'high')

# %%
cleaned = data.where(data['G3'] < 3, 'low').where(data['G3'] >= 3, 'high')

# %%
def transform_por_data(filepath):
# Out:
#     school  sex  age address famsize Pstatus Medu Fedu Mjob Fjob  ... famrel  \
# 0      low  low  low     low     low     low  low  low  low  low  ...    low
# 1      low  low  low     low     low     low  low  low  low  low  ...    low
# 2      low  low  low     low     low     low  low  low  low  low  ...    low
# 3      low  low  low     low     low     low  low  low  low  low  ...    low
# 4      low  low  low     low     low     low  low  low  low  low  ...    low
# ..     ...  ...  ...     ...     ...     ...  ...  ...  ...  ...  ...    ...
# 644    low  low  low     low     low     low  low  low  low  low  ...    low
# 645    low  low  low     low     low     low  low  low  low  low  ...    low
# 646    low  low  low     low     low     low  low  low  low  low  ...    low
# 647    low  low  low     low     low     low  low  low  low  low  ...    low
# 648    low  low  low     low     low     low  low  low  low  low  ...    low
#
# ...
